# %% [markdown]
# #### Giovanna Louzi Bellonia - 2017086015

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# Escolha uma imagem em escala de cinza e uma colorida (RGB).
#
# Escreva o código para carregar e mostrar ambas imagens.

# %%
#plotando a imagem colorida

img1 = mpimg.imread ('avengers.jpg')
plt.imshow(img1)
plt.show()

# %%
#transformamdo a imagem em preto e branco
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img2 = io.imread('dr_strange.jpeg')     
gray = rgb2gray(img2)    

#salvando a versao em preto e branco
fig = plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.axis('off')
fig.axes.get_xaxis().set_visible(False)
fig.axes.get_yaxis().set_visible(False)
plt.savefig('dr_strangePB.png', transparent = True, bbox_inches='tight', pad_inches = 0)

plt.show()

# %% [markdown]
# Escreva o código para criar e mostrar o histograma de ambas as imagens.

# %%
color = [ 'r','g','b']
for i, c in enumerate(color) :
    plt.hist(img1[:,:,i].flatten(),256, color=c)
    plt.show()

# %%
color = [ 'r','g','b']
for i, c in enumerate(color) :
    plt.hist(img2[:,:,i].flatten(),256, color=c)
    plt.show()
